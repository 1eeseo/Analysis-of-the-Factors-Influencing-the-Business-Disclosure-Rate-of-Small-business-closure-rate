# %% [markdown]
# # 서울시상권분석서비스 전체 데이터

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path1 = '/content/drive/MyDrive/파이썬 시각화/data/서울시 상권분석서비스 전체업종.csv'

# %%
import chardet

def detect_encoding(file_path):
    with open(file_path, 'rb') as f:
        result = chardet.detect(f.read())
        return result['encoding']

# 각 파일의 인코딩 감지
encoding1 = detect_encoding(path1)

df = pd.read_csv(path1, encoding=encoding1)

# %%
# 년도별, 분기별 시각화 하기 위해 컬럼 생성

df['년'] = df['기준_년분기_코드'].str.split(' ').str[0].str.replace('년', '')
df['분기'] = df['기준_년분기_코드'].str.split(' ').str[1].str.replace('월', '')

# 24 -> 2024 형태로 변환
df['년'] = '20' + df['년']

# 년-분기를 datetime 형식으로 변환
df['년_분기'] = pd.to_datetime(df['년'] + '-' + df['분기'], format='%Y-%m')

# YYYY-MM 형식으로 변환
df['년_분기'] = df['년_분기'].dt.strftime('%Y-%m')

df.head()
# Out:
#   기준_년분기_코드 자치구_코드_명 서비스_업종_코드_명  점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수     년 분기  \
# 0    24년 2월      강동구      전자상거래업  1954   3.1       60           4  2024  2
# 1    24년 2월      강동구         주유소    37   2.7        1           0  2024  2
# 2    24년 2월      강동구         예술품    32   3.1        1           0  2024  2
# 3    24년 2월      강동구    재생용품 판매점    38   5.3        2           0  2024  2
# 4    24년 2월      강동구    모터사이클및부품    19   0.0        0           0  2024  2
#
#       년_분기
# 0  2024-02
# 1  2024-02
# 2  2024-02
# 3  2024-02
# 4  2024-02

# %%
# 기존에 있던 년분기 코드 삭제
df = df.drop(columns = ['기준_년분기_코드'])

df.head()
# Out:
#   자치구_코드_명 서비스_업종_코드_명  점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수     년 분기     년_분기
# 0      강동구      전자상거래업  1954   3.1       60           4  2024  2  2024-02
# 1      강동구         주유소    37   2.7        1           0  2024  2  2024-02
# 2      강동구         예술품    32   3.1        1           0  2024  2  2024-02
# 3      강동구    재생용품 판매점    38   5.3        2           0  2024  2  2024-02
# 4      강동구    모터사이클및부품    19   0.0        0           0  2024  2  2024-02
